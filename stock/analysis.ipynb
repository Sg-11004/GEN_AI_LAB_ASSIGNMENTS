# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv('stock_data.csv')

# %%
X = data['Open'].values.reshape(-1,1)
y = data['Close'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Open')
plt.ylabel('Close')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print("accuracy percentage: ", model.score(X_test, y_test)*100)
# Out:
# Mean Absolute Error: 1.719338564799644
# Mean Squared Error: 5.624758479336183
# accuracy percentage:  99.46870744010432

# %%
#Performing Dimensionality Reduction and then Linear Regression

from sklearn.decomposition import PCA

pca = PCA(n_components=1)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Open')
plt.ylabel('Close')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print("accuracy percentage: ", model.score(X_test, y_test)*100)
# Out:
# Mean Absolute Error: 1.7193385647996449
# Mean Squared Error: 5.62475847933619
# accuracy percentage:  99.46870744010432
